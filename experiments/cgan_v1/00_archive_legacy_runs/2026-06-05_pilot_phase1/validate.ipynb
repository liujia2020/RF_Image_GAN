# %% [markdown]
# # 2026-06-05_pilot_phase1 validate placeholder
#
# Validation is not available because no model has been trained. Formal validation must export NIfTI, metrics, fixed figures, and verdict materials.
