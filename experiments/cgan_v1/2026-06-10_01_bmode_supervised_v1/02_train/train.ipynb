# %% [markdown]
# # Cell1 自检

# %%
import importlib
import train
importlib.reload(train)
config = train.load_config()
train.ensure_dirs()
cell1 = train.cell1_self_check(config)
cell1
# Out:
# {'timestamp': '2026-06-10 00:25:01 +0800',
#  'rf_cache_dir': '/home/liujia/rf_training_cache/cgan_phase2a_64x32x32_random_full1500_fp16_cache_20260607',
#  'bmode_gt_dir': '/home/liujia/rf_training_cache/cgan_phase2a_64x32x32_bmode_gt_ref64407p58_20260610',
#  'available_memory_gb': 55.09806823730469,
#  'use_amp': False,
#  'num_workers': 0,
#  'batch_categories': ['carotid', 'muscle', 'phantom'],
#  'batch_stats': {'input': {'shape': [3, 1536, 64, 32, 32],
#    'dtype': 'torch.float32',
#    'min': -9568.853515625,
#    'max': 10619.09375,
#    'mean': -0.020570039749145508,
#    'has_nan': False,
#    'has_inf': False},
#   'gt_bmode': {'shape': [3, 1, 64, 32, 32],
#    'dtype': 'torch.float32',
#    'min': 0.0,
#    'max': 0.85205078125,
#    'mean': 0.5201820731163025,
#    'has_nan': False,
#    'has_inf': False},
#   'baseline_bmode': {'shape': [3, 1, 64, 32, 32],
#    'dtype': 'torch.float32',
#    'min': 0.0,
#    'max': 0.9604097604751587,
#    'mean': 0.6486425995826721,
#    'has_nan': False,
#    'has_inf': False}},
#  'pred_stats': {'shape': [3, 1, 64, 32, 32],
#   'min': 0.5,
#   'max': 0.5,
#   'mean': 0.5,
#   'has_nan': False,
#   'has_inf': False},
#  'loss_probe': {'loss': 0.7616170048713684,
#   'ssim': 0.11596377193927765,
#   'l1': 0.11891625821590424},
#  'ssim_library': 'pytorch-msssim',
#  'ssim_parameters': {'library': 'pytorch-msssim',
#   'class': 'SSIM',
#   'spatial_dims': 3,
#   'scale': 'single',
#   'win_size': 7,
#   'win_sigma': 1.5,
#   'data_range': 1.0,
#   'channel': 1,
#   'nonnegative_ssim': True},
#  'status': 'self_check_passed'}

# %% [markdown]
# # Cell2 配置

# %%
cell2 = train.cell2_config(config)
cell2
# Out:
# {'run_name': '2026-06-10_01_bmode_supervised_v1',
#  'rf_cache_dir': '/home/liujia/rf_training_cache/cgan_phase2a_64x32x32_random_full1500_fp16_cache_20260607',
#  'bmode_gt_dir': '/home/liujia/rf_training_cache/cgan_phase2a_64x32x32_bmode_gt_ref64407p58_20260610',
#  'epochs': 50,
#  'loss': {'type': 'supervised_l1_ssim3d',
#   'lambda_ssim': 0.84,
#   'lambda_l1': 0.16,
#   'ssim': {'library': 'pytorch-msssim',
#    'class': 'SSIM',
#    'spatial_dims': 3,
#    'scale': 'single',
#    'win_size': 7,
#    'win_sigma': 1.5,
#    'data_range': 1.0,
#    'channel': 1,
#    'nonnegative_ssim': True}},
#  'sampler': {'type': 'stratified_category_batch_sampler',
#   'samples_per_category': 1,
#   'effective_batch_size': 3,
#   'shuffle': True,
#   'seed': 20260610},
#  'generator': {'model_class': 'TinyBModeRFNet',
#   'basis': 'TinyResidualRFNet conv stack',
#   'input_channels': 1536,
#   'hidden_channels': 64,
#   'output_channels': 1,
#   'use_bn': True,
#   'output_activation': 'sigmoid',
#   'baseline_used_by_model': False,
#   'init': 'random_zero_last_layer'}}

# %% [markdown]
# # Cell3 数据

# %%
data_state = train.cell3_data(config)
data_state['summary']
# Out:
# {'train_samples': 1050, 'val_samples': 225}

# %% [markdown]
# # Cell4 模型

# %%
model_state = train.cell4_model(config)
model_state['summary']
# Out:
# {'device': 'cuda',
#  'G_params': 264705,
#  'model_class': 'TinyBModeRFNet',
#  'output_activation': 'sigmoid',
#  'baseline_used_by_model': False,
#  'ssim_library': 'pytorch-msssim',
#  'ssim_parameters': {'library': 'pytorch-msssim',
#   'class': 'SSIM',
#   'spatial_dims': 3,
#   'scale': 'single',
#   'win_size': 7,
#   'win_sigma': 1.5,
#   'data_range': 1.0,
#   'channel': 1,
#   'nonnegative_ssim': True}}

# %% [markdown]
# # Cell5 训练循环

# %%
cell5 = train.cell5_train(config, data_state, model_state['models'])
cell5
# Out:
# EPOCH 001/50 loss=0.746908 ssim=0.131352 l1=0.107774 val_loss=0.738592 seconds=465.7
# EPOCH 002/50 loss=0.729254 ssim=0.151049 l1=0.100842 val_loss=0.737223 seconds=465.4
# EPOCH 003/50 loss=0.719470 ssim=0.162695 l1=0.100840 val_loss=0.738338 seconds=465.2
# EPOCH 004/50 loss=0.709236 ssim=0.174889 l1=0.100894 val_loss=0.741323 seconds=463.0
# EPOCH 005/50 loss=0.700682 ssim=0.185072 l1=0.100889 val_loss=0.744084 seconds=469.9
# EPOCH 006/50 loss=0.693628 ssim=0.193436 l1=0.100714 val_loss=0.747228 seconds=461.2
# EPOCH 007/50 loss=0.687789 ssim=0.200371 l1=0.100632 val_loss=0.750161 seconds=467.6
# EPOCH 008/50 loss=0.682905 ssim=0.206180 l1=0.100597 val_loss=0.752640 seconds=467.6
# EPOCH 009/50 loss=0.678735 ssim=0.211145 l1=0.100604 val_loss=0.755089 seconds=462.0
# EPOCH 010/50 loss=0.675122 ssim=0.215443 l1=0.100589 val_loss=0.757361 seconds=461.6
# EPOCH 011/50 loss=0.671966 ssim=0.219193 l1=0.100549 val_loss=0.758820 seconds=460.1
# EPOCH 012/50 loss=0.669162 ssim=0.222530 l1=0.100546 val_loss=0.760181 seconds=462.0
# EPOCH 013/50 loss=0.666637 ssim=0.225528 l1=0.100501 val_loss=0.761262 seconds=461.2
# EPOCH 014/50 loss=0.664356 ssim=0.228235 l1=0.100454 val_loss=0.762484 seconds=460.4
# EPOCH 015/50 loss=0.662275 ssim=0.230702 l1=0.100408 val_loss=0.763567 seconds=461.4
# EPOCH 016/50 loss=0.660376 ssim=0.232956 l1=0.100369 val_loss=0.764475 seconds=461.7
# EPOCH 044/50 loss=0.634126 ssim=0.264053 l1=0.099568 val_loss=0.775277 seconds=470.7
# EPOCH 045/50 loss=0.633615 ssim=0.264657 l1=0.099544 val_loss=0.775152 seconds=478.2
# EPOCH 046/50 loss=0.633143 ssim=0.265221 l1=0.099558 val_loss=0.775332 seconds=478.0
# EPOCH 047/50 loss=0.632655 ssim=0.265800 l1=0.099547 val_loss=0.775306 seconds=473.8
# EPOCH 048/50 loss=0.632163 ssim=0.266381 l1=0.099516 val_loss=0.775236 seconds=473.9
# EPOCH 049/50 loss=0.631718 ssim=0.266909 l1=0.099511 val_loss=0.775267 seconds=480.6
# EPOCH 050/50 loss=0.631282 ssim=0.267425 l1=0.099493 val_loss=0.775056 seconds=467.2
# {'timestamp': '2026-06-10 06:52:23 +0800',
#  'status': 'completed_50_epochs',
#  'epochs': 50,
#  'total_seconds': 23241.834224939346,
#  'first_epoch': {'epoch': 1,
#   'batches': 350,
#   'seconds': 465.6767897605896,
#   'peak_cuda_mem_gb': 2.3596763610839844,
#   'available_memory_gb': 49.958438873291016,
#   'loss': 0.7469080587795802,
#   'ssim': 0.1313521792633193,
#   'l1': 0.10777446029441698,
#   'pred_min': 0.4221411637748991,
#   'pred_max': 0.981391191482544,
#   'pred_mean': 0.5261741963454655,
#   'pred_baseline_l1': 0.1502046847875629,
#   'baseline_gt_l1': 0.15036506972142627,
#   'pred_gt_l1': 0.10777446029441698,
#   'has_nan': 0.0,
#   'has_inf': 0.0,
#   'val_loss': 0.738592267036438,
#   'val_ssim': 0.13778246194124222,
#   'val_l1': 0.08955973200500011,
#   'val_pred_baseline_l1': 0.16756439954042435,
#   'val_baseline_gt_l1': 0.14964335970580578},
#  'last_epoch': {'epoch': 50,
#   'batches': 350,
#   'seconds': 467.1605348587036,
#   'peak_cuda_mem_gb': 2.3596763610839844,
#   'available_memory_gb': 49.62434005737305,
#   'loss': 0.6312817306177957,
#   'ssim': 0.26742506959608625,
#   'l1': 0.0994925966007369,
#   'pred_min': 0.17964567105684962,
#   'pred_max': 0.9983944296836853,
#   'pred_mean': 0.5280537661484309,
#   'pred_baseline_l1': 0.1440938641130924,
#   'baseline_gt_l1': 0.15036506972142627,
#   'pred_gt_l1': 0.0994925966007369,
#   'has_nan': 0.0,
#   'has_inf': 0.0,
#   'val_loss': 0.7750561162829399,
#   'val_ssim': 0.09799201227724552,
#   'val_l1': 0.1085588913410902,
#   'val_pred_baseline_l1': 0.19586090371012688,
#   'val_baseline_gt_l1': 0.14964335970580578},
#  'outputs': {'stability_csv': '/media/liujia/8CC24D13C24D02C6/code/RF_Image_GAN/experiments/cgan_v1/2026-06-10_01_bmode_supervised_v1/02_train/metrics/stability.csv',
#   'figures_dir': '/media/liujia/8CC24D13C24D02C6/code/RF_Image_GAN/experiments/cgan_v1/2026-06-10_01_bmode_supervised_v1/02_train/figures',
#   'checkpoints_dir': '/media/liujia/8CC24D13C24D02C6/code/RF_Image_GAN/experiments/cgan_v1/2026-06-10_01_bmode_supervised_v1/02_train/checkpoints'}}

# %% [markdown]
# # Cell6 损失曲线

# %%
cell6 = train.cell6_loss_curves()
cell6
# Out:
# {'loss_curve': '/media/liujia/8CC24D13C24D02C6/code/RF_Image_GAN/experiments/cgan_v1/2026-06-10_01_bmode_supervised_v1/02_train/figures/bmode_supervised_loss_curves.png',
#  'rows': 50}

# %% [markdown]
# # Cell7 清理

# %%
cell7 = train.cell7_cleanup()
cell7
# Out:
# {'lock_removed': True, 'timestamp': '2026-06-10 06:52:23 +0800'}

# %% [markdown]
# # Cell8 自动摘要

# %%
cell8 = train.cell8_summary(config)
cell8
# Out:
# {'run_name': '2026-06-10_01_bmode_supervised_v1',
#  'timestamp': '2026-06-10 06:52:23 +0800',
#  'metrics_rows': 50,
#  'ssim_library': 'pytorch-msssim',
#  'ssim_parameters': {'library': 'pytorch-msssim',
#   'class': 'SSIM',
#   'spatial_dims': 3,
#   'scale': 'single',
#   'win_size': 7,
#   'win_sigma': 1.5,
#   'data_range': 1.0,
#   'channel': 1,
#   'nonnegative_ssim': True},
#  'first_epoch': {'epoch': '1',
#   'batches': '350',
#   'seconds': '465.6767897605896',
#   'peak_cuda_mem_gb': '2.3596763610839844',
#   'available_memory_gb': '49.958438873291016',
#   'loss': '0.7469080587795802',
#   'ssim': '0.1313521792633193',
#   'l1': '0.10777446029441698',
#   'pred_min': '0.4221411637748991',
#   'pred_max': '0.981391191482544',
#   'pred_mean': '0.5261741963454655',
#   'pred_baseline_l1': '0.1502046847875629',
#   'baseline_gt_l1': '0.15036506972142627',
#   'pred_gt_l1': '0.10777446029441698',
#   'has_nan': '0.0',
#   'has_inf': '0.0',
#   'val_loss': '0.738592267036438',
#   'val_ssim': '0.13778246194124222',
#   'val_l1': '0.08955973200500011',
#   'val_pred_baseline_l1': '0.16756439954042435',
#   'val_baseline_gt_l1': '0.14964335970580578'},
#  'last_epoch': {'epoch': '50',
#   'batches': '350',
#   'seconds': '467.1605348587036',
#   'peak_cuda_mem_gb': '2.3596763610839844',
#   'available_memory_gb': '49.62434005737305',
#   'loss': '0.6312817306177957',
#   'ssim': '0.26742506959608625',
#   'l1': '0.0994925966007369',
#   'pred_min': '0.17964567105684962',
#   'pred_max': '0.9983944296836853',
#   'pred_mean': '0.5280537661484309',
#   'pred_baseline_l1': '0.1440938641130924',
#   'baseline_gt_l1': '0.15036506972142627',
#   'pred_gt_l1': '0.0994925966007369',
#   'has_nan': '0.0',
#   'has_inf': '0.0',
#   'val_loss': '0.7750561162829399',
#   'val_ssim': '0.09799201227724552',
#   'val_l1': '0.1085588913410902',
#   'val_pred_baseline_l1': '0.19586090371012688',
#   'val_baseline_gt_l1': '0.14964335970580578'},
#  'quality_conclusion': 'none; requires later 3D Slicer review'}
